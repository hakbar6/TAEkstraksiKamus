# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %%
directory = "[Full] CSV JSON all information"

# %%
def count_font_bold(data):
    cnt = 0
    for i in data:
        if "bold" in i.lower():
            cnt += 1
    return cnt

def count_font_italic(data):
    cnt = 0
    for i in data:
        if "italic" in i.lower():
            cnt += 1
    return cnt

# %%
page = [1,1,1,1,2,2,2,2,]

page = np.array(page)
page = np.unique(page)
page[-1]
# Out:
# 2

# %%
result = {
    "nama_kamus":[],
    "jumlah_bold":[],
    "jumlah_italic":[],
    "mean_ukuran_char":[],
    "banyak_halaman":[]
}

for filename in tqdm(os.listdir(directory)):
    data = pd.read_csv(directory + "/" + filename)
    
    sum_bold = count_font_bold(data["font"].values.tolist())
    sum_italic = count_font_italic(data["font"].values.tolist())
    
    size = data["size"].values.tolist()

    page = np.array(data["page"].values.tolist())
    page = np.unique(page)
    
    result['nama_kamus'].append(filename)
    result['jumlah_bold'].append(sum_bold)
    result['jumlah_italic'].append(sum_italic)
    result['mean_ukuran_char'].append(round(np.mean(size),2))
    result['banyak_halaman'].append(len(page))
# Out:
#  98%|████████████████████████████████████████████████████████████████████████████████▋ | 61/62 [00:22<00:00,  2.70it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'font'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17372\2197967411.py in <module>
#      10     data = pd.read_csv(directory + "/" + filename)
#      11
# ---> 12     sum_bold = count_font_bold(data["font"].values.tolist())
#      13     sum_italic = count_font_italic(data["font"].values.tolist())
#      14
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'font'

# %%
pandas_res = pd.DataFrame.from_dict(result)
# tampilkan seluruh baris dan seluruh nilai pada kolom
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

display(pandas_res)

# reset option
pd.reset_option("display")

pandas_res.to_csv(directory + "/exploratory_kamus_analysis.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19924\1865996647.py in <module>
# ----> 1 pandas_res = pd.DataFrame.from_dict(result)
#       2 # tampilkan seluruh baris dan seluruh nilai pada kolom
#       3 pd.set_option('display.max_rows', None)
#       4 pd.set_option('display.max_colwidth', None)
#       5
#
# NameError: name 'result' is not defined

# %%
pandas_res = pd.read_csv(directory + "/exploratory_kamus_analysis.csv")

pandas_res = pandas_res[(pandas_res["jumlah_bold"] >= pandas_res["banyak_halaman"]) & (pandas_res["jumlah_italic"] >= pandas_res["banyak_halaman"])]
pandas_res = pandas_res.reset_index(drop=True)
# tampilkan seluruh baris dan seluruh nilai pada kolom
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pandas_res.to_csv("daftar_kamus_ekstraks.csv",index=False)

display(pandas_res)

# reset option
pd.reset_option("display")
# Out:
#                                                                          nama_kamus  \
# 0          10. Kamus Bahasa Indonesia-Dayak Deah Edisi I (2013)-hasil-ekstraksi.csv
# 1               12. Kamus Bahasa Indonesia-Kaidipang L-Z (2000)-hasil-ekstraksi.csv
# 2       14. Kamus Bahasa Indonesia-Bahasa Minangkabau II (1994)-hasil-ekstraksi.csv
# 3                       15. Kamus Bahasa Indonesia-Pasir (1997)-hasil-ekstraksi.csv
# 4                    16. Kamus Bahasa Indonesia Karo A-K (1998)-hasil-ekstraksi.csv
# 5                     17. Kamus Melayu Makasar-Indonesia (1985)-hasil-ekstraksi.csv
# 6               18. Kamus Bahasa Jawa-Bahasa Indonesia I (1993)-hasil-ekstraksi.csv
# 7                 19. Kamus Bahasa Indoensia-Melayu Riau (1997)-hasil-ekstraksi.csv
# 8                              2. Kamus Melayu-Indonesia (1985)-hasil-ekstraksi.csv
# 9                20. Kamus Bahasa Melayu Ambon-Indonesia (1998)-hasil-ekstraksi.csv
# 10                21. Kamus Bahasa Indonesia-Sentani A-K (1999)-hasil-ekstraksi.csv
# 11             23. Kamus Dwibahasa Dayak Ngaju-Indonesia (2013)-hasil-ekstraksi.csv
# 12                       24. Kamus Minangkabau-Indonesia (1985)-hasil-ekstraksi.csv
# 13           26. Kamus Bahasa Indonesia-Bahasa Tonsea II (1996)-hasil-ekstraksi.csv
# 14                     27. Kamus Bahasa Indonesia-Saluan (2012)-hasil-ekstraksi.csv
# 15               28. Kamus Bahasa Kutai-Bahasa Indonesia (2013)-hasil-ekstraksi.csv
# 16                              29. Kata Tetun Indonesia (1985)-hasil-ekstraksi.csv
# 17                           31. Kamus Sumbawa-Indonesia (1985)-hasil-ekstraksi.csv
# 18                    32. Kamus Melayu Langkat-Indonesia (1985)-hasil-ekstraksi.csv
# 19                             33. Kamus Wolio Indonesia (1985)-hasil-ekstraksi.csv
# 20                   34. Kamus Bahasa Indonesia-Bali L-Z (1998)-hasil-ekstraksi.csv
# 21                     36. Kamus Bahasa Indonesia-Kulawi (2012)-hasil-ekstraksi.csv
# 22                   38. Kamus Bahasa Indonesia-Karo L-Z (1999)-hasil-ekstraksi.csv
# 23                   4. Kamus Bahasa Indonesia-Jambi A-K (1998)-hasil-ekstraksi.csv
# 24                   41. Kamus Bahasa Indonesia-Bali A-K (1997)-hasil-ekstraksi.csv
# 25            42. Kamus Bahasa Indonesia-Bahasa Sunda II (1993)-hasil-ekstraksi.csv
# 26                       44. Kamus Melayu Deli-Indonesia (1985)-hasil-ekstraksi.csv
# 27         46. Kamus Bahasa Banjar Dialek Hulu-Indonesia (2008)-hasil-ekstraksi.csv
# 28             5. Kamus Bahasa Indonesia-Bahasa Tonsea I (1996)-hasil-ekstraksi.csv
# 29                  51. Kamus Bahasa Bali Kuno-Indonesia (1985)-hasil-ekstraksi.csv
# 30                              52. Kamus Ogan-Indonesia (1985)-hasil-ekstraksi.csv
# 31                   54. Kamus Bahasa Indonesia Mentawai (1998)-hasil-ekstraksi.csv
# 32                 55. Kamus Bahasa Indonesia Bakumpai I (1995)-hasil-ekstraksi.csv
# 33                           56. Kamus Lampung-Indonesia (1985)-hasil-ekstraksi.csv
# 34               58. Kamus Melayu Ketapang-Indonesia A-M (2010)-hasil-ekstraksi.csv
# 35                             60. Kamus Sunda-Indonesia (1985)-hasil-ekstraksi.csv
# 36           63. Kamus Bahasa Indonesia-Lampung Dialek A (1999)-hasil-ekstraksi.csv
# 37                       66. Kamus Melayu Bali-Indonesia (1985)-hasil-ekstraksi.csv
# 38  68. Kamus Dwibahasa Bahasa Talaud - Bahasa Indonesia (2018)-hasil-ekstraksi.csv
# 39                   71. Kamus dwibahasa Bugis-Indonesia (2017)-hasil-ekstraksi.csv
# 40                            78. Kamus Tolaki-Indonesia (1985)-hasil-ekstraksi.csv
# 41                            8. Kamus Indonesia-Angkola (1995)-hasil-ekstraksi.csv
# 42                           85. Kamus Tondano-Indonesia (1985)-hasil-ekstraksi.csv
# 43            87. Kamus Bahasa Indonesia-Kaidipang (A-K) (1999)-hasil-ekstraksi.csv
# 44      89. Kamus Dwibahasa Bahasa Mooi-Bahasa Indonesia (2017)-hasil-ekstraksi.csv
# 45                             9. Kamus Manado-Indonesia (1985)-hasil-ekstraksi.csv
# 46        91. Kamus Simalungun - Indonesia (edisi kedua) (2015)-hasil-ekstraksi.csv
#
#     jumlah_bold  jumlah_italic  mean_ukuran_char  banyak_halaman
# 0          5634          17598              9.07             300
# 1         12390          28518             11.17             512
# 2           604          30562             10.79             465
# 3           673          39742             10.74             529
# 4          2257          28938             10.36             401
# 5          2911          12870             10.46             143
# 6         20536           8646             11.14             450
# 7          9506          29084             11.56             436
# 8          7605          15208             10.72             229
# 9          2234          12641             11.80             138
# 10         5112          15126             11.51             182
# 11         3587            631              8.99             154
# 12        12236          26484             10.37             312
# 13         5364           2714             11.11             168
# 14         9318          11371             10.52             120
# 15          819          27928             10.59             436
# 16         3152          12972             10.59             118
# 17          483          10553              9.31             167
# 18         3385           8326             10.25             183
# 19         2923          12944             10.74             191
# 20        16336          18827             10.77             498
# 21         1443          21190              9.60             222
# 22         2113          30006             10.86             584
# 23         4029          23570             11.41             208
# 24        16912          24003             11.65             451
# 25         6369          35812             11.33             486
# 26         2216           8196             10.51             117
# 27        27399          37333              8.90             310
# 28         4751           2146             11.17             148
# 29         1947           5718             10.14             122
# 30         6833          21536             10.78             249
# 31         2916           9212             11.09             108
# 32         2334          19643             11.29             198
# 33         4696          19685             10.72             215
# 34         5846           1723              9.46             159
# 35          480           8381              9.09             382
# 36          972          13724             10.77             321
# 37         2114           8779             10.42             126
# 38        12659          17602             11.02             283
# 39         1201           3597             11.02              49
# 40          179          13280              9.67             160
# 41          310           4415              8.80             154
# 42         1229          16617              9.25             295
# 43          878          30145             10.71             525
# 44         1575           5231             11.95              78
# 45         8908          10412              9.32             136
# 46        13465          33758              9.98             264

# %%
pandas_res = pd.read_csv(directory + "/exploratory_kamus_analysis.csv")

pandas_res = pandas_res[(pandas_res["jumlah_bold"] < pandas_res["banyak_halaman"]) | (pandas_res["jumlah_italic"] < pandas_res["banyak_halaman"])]
pandas_res = pandas_res.reset_index(drop=True)
# tampilkan seluruh baris dan seluruh nilai pada kolom
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

display(pandas_res)

# reset option
pd.reset_option("display")
pandas_res.to_csv("daftar kamus yang tidak diekstrak.csv",index=False)
# Out:
#                                                               nama_kamus  \
# 0                  11. Kamus Suwawa-Indonesia (1985)-hasil-ekstraksi.csv
# 1   13. Kamus Bahasa Indonesia-Bahasa Sunda I (1993)-hasil-ekstraksi.csv
# 2        22. Kamus Bahasa Gorontalo-Indonesia (1977)-hasil-ekstraksi.csv
# 3        25. Kamus Bahasa Indonesia Jambi L-Z (1997)-hasil-ekstraksi.csv
# 4         3. Kamus Bahasa Gorontalo-Indonesia (2001)-hasil-ekstraksi.csv
# 5      37. Kamus Bahasa Indonesia Bakumpai II (1995)-hasil-ekstraksi.csv
# 6                    48. Kamus Muna-Indonesia (1985)-hasil-ekstraksi.csv
# 7               50. Kamus Indonesia-Jawa Kuno (1992)-hasil-ekstraksi.csv
# 8              67. Kamus Aceh Indonesia (A-L) (1985)-hasil-ekstraksi.csv
# 9        70. Kamus dwibahasa Hitu - Indonesia (2017)-hasil-ekstraksi.csv
# 10   74. Kamus Bahasa Melayu Bangka-Indonesia (2018)-hasil-ekstraksi.csv
# 11  79. Kamus Bahasa Jawa-Bahasa Indonesia II (1993)-hasil-ekstraksi.csv
# 12         84. Kamus Bahasa Biak - Indonesia (1977) -hasil-ekstraksi.csv
# 13          94. Kamus Bahasa Madura-Indonesia (1977)-hasil-ekstraksi.csv
#
#     jumlah_bold  jumlah_italic  mean_ukuran_char  banyak_halaman
# 0             4          34928              9.41             335
# 1           317          22602             10.55             408
# 2            37          37553              8.42             302
# 3           136          32818             11.26             332
# 4            62          37204              8.19             302
# 5            42          22995             10.64             250
# 6           124          10311              9.78             140
# 7            13           3312              9.59             172
# 8           112          48446              9.66             560
# 9             3            297             10.74              80
# 10         3627              0             11.98             156
# 11           13           7670             10.89             415
# 12            1           9565              8.33              79
# 13          126          14027              7.90             208
