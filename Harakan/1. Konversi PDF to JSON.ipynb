# %%
import fitz
import json
import os
import pandas as pd

# %%
class BytesEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, bytes):
            return obj.decode('utf-16')
        return json.JSONEncoder.default(self, obj)

# %%
from pathlib import Path
directory = "[Full] Daftar Kamus Ekstraksi"
directory_hasil = "[Full] Bentuk JSON"
pdfgagal = []

for filename in os.listdir(directory):
    print("=== Processing File " + filename + " ===")
    try:
        with open(directory + "/" + filename,"rb") as f:
            document = fitz.open(f)
        
        new_filename = os.path.splitext(filename)[0]
        with open(directory_hasil + "/" + new_filename + "-hasil.json", "w",encoding="utf-8") as t:
            counter = 0
            result = {}
            for page in document:
                data = {}
                value = page.get_text('dict')
                for i in value['blocks']:
                    try:
                        i.pop('image')
                    except:
                        continue
                data["page"] = counter
                data["text"] = value
                result[str(counter)] = data
                counter += 1
            json.dump(result,t)
        
        f.close()
        t.close()
    except:
        print("=== File Gagal " + filename + " ===")
        pdfgagal.append(filename)
# Out:
# === Processing File 1. Kamus Makasar-Indonesia (1995).pdf ===
# === Processing File 10. Kamus Bahasa Indonesia-Dayak Deah Edisi I (2013).pdf ===
# === Processing File 11. Kamus Suwawa-Indonesia (1985).pdf ===
# === Processing File 12. Kamus Bahasa Indonesia-Kaidipang L-Z (2000).pdf ===
# === Processing File 13. Kamus Bahasa Indonesia-Bahasa Sunda I (1993).pdf ===
# === Processing File 14. Kamus Bahasa Indonesia-Bahasa Minangkabau II (1994).pdf ===
# === Processing File 15. Kamus Bahasa Indonesia-Pasir (1997).pdf ===
# === Processing File 16. Kamus Bahasa Indonesia Karo A-K (1998).pdf ===
# === Processing File 17. Kamus Melayu Makasar-Indonesia (1985).pdf ===
# === Processing File 18. Kamus Bahasa Jawa-Bahasa Indonesia I (1993).pdf ===
# === Processing File 19. Kamus Bahasa Indoensia-Melayu Riau (1997).pdf ===
# === Processing File 2. Kamus Melayu-Indonesia (1985).pdf ===
# === Processing File 20. Kamus Bahasa Melayu Ambon-Indonesia (1998).pdf ===
# === Processing File 21. Kamus Bahasa Indonesia-Sentani A-K (1999).pdf ===
# === Processing File 22. Kamus Bahasa Gorontalo-Indonesia (1977).pdf ===
# === Processing File 23. Kamus Dwibahasa Dayak Ngaju-Indonesia (2013).pdf ===
# === Processing File 24. Kamus Minangkabau-Indonesia (1985).pdf ===
# === Processing File 25. Kamus Bahasa Indonesia Jambi L-Z (1997).pdf ===
# === Processing File 26. Kamus Bahasa Indonesia-Bahasa Tonsea II (1996).pdf ===
# === Processing File 27. Kamus Bahasa Indonesia-Saluan (2012).pdf ===
# === Processing File 28. Kamus Bahasa Kutai-Bahasa Indonesia (2013).pdf ===
# === Processing File 29. Kata Tetun Indonesia (1985).pdf ===
